# %%
import pandas as pd

# %%
df=pd.read_csv("fifa_data.csv")
pd.set_option("display.max_columns",None)
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
#  # Which Country has the most number of players

# %%
df["Nationality"].value_counts().idxmax()
# Out:
# 'England'

# %% [markdown]
#  # find the tallest player using the height column?

# %%
df["Height"].value_counts()
# Out:
# 6'0     2881
# 5'10    2479
# 5'9     2238
# 5'11    2159
# 6'2     2015
# 6'1     1908
# 6'3      990
# 5'8      946
# 5'7      905
# 6'4      749
# 5'6      316
# 6'5      246
# 5'5      145
# 6'6       93
# 5'4       30
# 6'7       21
# 5'3       18
# 6'8       10
# 5'2        5
# 5'1        3
# 6'9        2
# Name: Height, dtype: int64

# %%
df["Height"].value_counts().min()
# Out:
# 2

# %%
df.sort_values(by='Height', ascending=False)[['Name', 'Height']]
# Out:
#                       Name Height
# 11614              T. Holý    6'9
# 17927            D. Hodzic    6'9
# 11903          K. Scherpen    6'8
# 17694             M. Casey    6'8
# 4189   V. Milinković-Savić    6'8
# ...                    ...    ...
# 13279         P. Mazzocchi    NaN
# 13280            Y. Ammour    NaN
# 13281       Jwa Joon Hyeop    NaN
# 13282           O. Marrufo    NaN
# 13283          Han Pengfei    NaN
#
# [18207 rows x 2 columns]

# %%
df.sort_values(by='Height', ascending=False)[['Name', 'Height']].max()
# Out:
# Series([], dtype: float64)

# %%
df.iloc[11614][['Name', 'Height']]
# Out:
# Name      T. Holý
# Height        6'9
# Name: 11614, dtype: object

# %% [markdown]
# # which club has the most number of players?

# %%
a=df["Club"].value_counts()
a[a==a.max()]
# Out:
# RC Celta                   33
# Newcastle United           33
# Borussia Dortmund          33
# Real Madrid                33
# Atlético Madrid            33
# Empoli                     33
# Southampton                33
# Chelsea                    33
# Cardiff City               33
# Manchester United          33
# Liverpool                  33
# Valencia CF                33
# FC Barcelona               33
# Rayo Vallecano             33
# Tottenham Hotspur          33
# AS Monaco                  33
# Wolverhampton Wanderers    33
# Fortuna Düsseldorf         33
# Eintracht Frankfurt        33
# Frosinone                  33
# Burnley                    33
# TSG 1899 Hoffenheim        33
# Manchester City            33
# CD Leganés                 33
# Everton                    33
# Arsenal                    33
# Name: Club, dtype: int64

# %% [markdown]
# # which foot is most preferred by players draw a bar chart for preferred foot

# %%
df["Preferred Foot"].value_counts()
# Out:
# Right    13948
# Left      4211
# Name: Preferred Foot, dtype: int64

# %%
import matplotlib.pyplot as plt

x = ["Right","Left"]
y = df["Preferred Foot"].value_counts()
plt.title("Preferred Foot")
plt.bar(x, y)
plt.show()

# %% [markdown]
# # plot a scatter plot on overall and potential

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("fifa_data.csv")
sns.scatterplot(x="Overall", y="Potential",data=df)
plt.xlabel("overall")
plt.ylabel("Potential")
plt.title("scatter plot")
plt.show()

# %% [markdown]
# # plot a histogram for salary range of players

# %%
x = df["Wage"]
plt.hist(x)
plt.show()

# %% [markdown]
# # barcelona player count

# %%
df["Club"].value_counts()["FC Barcelona"]
# Out:
# 33

# %%
df["Club"].value_counts()
# Out:
# RC Celta             33
# Newcastle United     33
# Borussia Dortmund    33
# Real Madrid          33
# Atlético Madrid      33
#                      ..
# Botafogo             20
# Chapecoense          20
# Limerick FC          19
# Sligo Rovers         19
# Derry City           18
# Name: Club, Length: 651, dtype: int64

# %%
bc = df[df["Club"] == "FC Barcelona"]
bc
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 0               0  158023         L. Messi   31
# 7               7  176580        L. Suárez   31
# 18             18  192448    M. ter Stegen   26
# 20             20  189511  Sergio Busquets   29
# 32             32  189242         Coutinho   26
# 42             42  205600        S. Umtiti   24
# 49             49  189332       Jordi Alba   29
# 53             53  168651       I. Rakitić   30
# 54             54  152729            Piqué   31
# 96             96  181872         A. Vidal   31
# 155           155  231443       O. Dembélé   21
# 192           192  199564    Sergi Roberto   26
# 228           228  230658           Arthur   21
# 236           236  222737           Malcom   21
# 239           239  220440       C. Lenglet   23
# 263           263  201400          Rafinha   25
# 266           266  199987     J. Cillessen   29
# 324           324  227928    Nélson Semedo   24
# ...

# %% [markdown]
# # Highest salary player and his name

# %%
df["Wage"]
# Out:
# 0        €565K
# 1        €405K
# 2        €290K
# 3        €260K
# 4        €355K
#          ...
# 18202      €1K
# 18203      €1K
# 18204      €1K
# 18205      €1K
# 18206      €1K
# Name: Wage, Length: 18207, dtype: object

# %%
#replace € value

# %%
df["Wage"]=df["Wage"].str.replace("€","")

# %%
df["Wage"]
# Out:
# 0        565K
# 1        405K
# 2        290K
# 3        260K
# 4        355K
#          ...
# 18202      1K
# 18203      1K
# 18204      1K
# 18205      1K
# 18206      1K
# Name: Wage, Length: 18207, dtype: object

# %%
#replace k value into 000

# %%
df["Wage"]=df["Wage"].str.replace("K","000")

# %%
df["Wage"]
# Out:
# 0        565000
# 1        405000
# 2        290000
# 3        260000
# 4        355000
#           ...
# 18202      1000
# 18203      1000
# 18204      1000
# 18205      1000
# 18206      1000
# Name: Wage, Length: 18207, dtype: object

# %%
df["Wage"]=df["Wage"].astype(int)

# %%
df["Name"]
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
# highest_salary_player

# %%
df[["Wage","Name"]].sort_values(by='Wage',ascending=False).loc[0]
# Out:
# Wage      565000
# Name    L. Messi
# Name: 0, dtype: object
